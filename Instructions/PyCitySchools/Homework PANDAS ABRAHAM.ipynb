# %%
#Dependencies
import csv
import pandas as pd
import numpy as np

# %%
# define csv file
schools_data = "raw_data/schools_complete.csv"
students_data = "raw_data/students_complete.csv"

# %%
schoolsdata_file_pd = pd.read_csv(schools_data)
schoolsdata_file_pd.head()
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
schoolsdata_file_pd.columns
# Out:
# Index(['School ID', 'name', 'type', 'size', 'budget'], dtype='object')

# %%
schoolsdata_file_pd.count()
# Out:
# School ID    15
# name         15
# type         15
# size         15
# budget       15
# dtype: int64

# %%
schoolsdata_file_pd.dtypes
# Out:
# School ID     int64
# name         object
# type         object
# size          int64
# budget        int64
# dtype: object

# %%
#update names of columns in school data

schoolsdataorg_df = schoolsdata_file_pd.rename(columns={"name":"School Name", "type":"School Type",
                                                       "size":"School Size", "budget":"School Budget"})
schoolsdataorg_df.head()
# Out:
#    School ID            School Name School Type  School Size  School Budget
# 0          0      Huang High School    District         2917        1910635
# 1          1   Figueroa High School    District         2949        1884411
# 2          2    Shelton High School     Charter         1761        1056600
# 3          3  Hernandez High School    District         4635        3022020
# 4          4    Griffin High School     Charter         1468         917500

# %%
#update formatting of School Size and School Budget

schoolsdataorg_df["School Size"] = schoolsdataorg_df["School Size"].map("{:,}".format)


schoolsdataorg_df.head()
# Out:
#    School ID            School Name School Type School Size  School Budget
# 0          0      Huang High School    District       2,917        1910635
# 1          1   Figueroa High School    District       2,949        1884411
# 2          2    Shelton High School     Charter       1,761        1056600
# 3          3  Hernandez High School    District       4,635        3022020
# 4          4    Griffin High School     Charter       1,468         917500

# %%
#read students_data csv file

studentsdata_file_pd = pd.read_csv(students_data)
studentsdata_file_pd.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
studentsdata_file_pd.columns
# Out:
# Index(['Student ID', 'name', 'gender', 'grade', 'school', 'reading_score',
#        'math_score'],
#       dtype='object')

# %%
studentsdata_file_pd.count()
# Out:
# Student ID       39170
# name             39170
# gender           39170
# grade            39170
# school           39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
studentsdata_file_pd.dtypes
# Out:
# Student ID        int64
# name             object
# gender           object
# grade            object
# school           object
# reading_score     int64
# math_score        int64
# dtype: object

# %%
studentsdataorg_df = studentsdata_file_pd.rename(columns={"name":"Student Name", "gender":"Gender",
                                                       "grade":"Grade Level", "school":"School Name",
                                                       "reading_score":"Reading Score", "math_score":"Math Score"})

studentsdataorg_df.head()
# Out:
#    Student ID       Student Name Gender Grade Level        School Name  \
# 0           0       Paul Bradley      M         9th  Huang High School
# 1           1       Victor Smith      M        12th  Huang High School
# 2           2    Kevin Rodriguez      M        12th  Huang High School
# 3           3  Dr. Richard Scott      M        12th  Huang High School
# 4           4         Bonnie Ray      F         9th  Huang High School
#
#    Reading Score  Math Score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
student_school_merge_df = pd.merge(studentsdataorg_df, schoolsdataorg_df, how="left", on=["School Name", "School Name"])

student_school_merge_df.head(25)
# Out:
#     Student ID        Student Name Gender Grade Level        School Name  \
# 0            0        Paul Bradley      M         9th  Huang High School
# 1            1        Victor Smith      M        12th  Huang High School
# 2            2     Kevin Rodriguez      M        12th  Huang High School
# 3            3   Dr. Richard Scott      M        12th  Huang High School
# 4            4          Bonnie Ray      F         9th  Huang High School
# 5            5       Bryan Miranda      M         9th  Huang High School
# 6            6       Sheena Carter      F        11th  Huang High School
# 7            7        Nicole Baker      F        12th  Huang High School
# 8            8        Michael Roth      M        10th  Huang High School
# 9            9      Matthew Greene      M        10th  Huang High School
# 10          10    Andrew Alexander      M        10th  Huang High School
# 11          11       Daniel Cooper      M        10th  Huang High School
# ...

# %%
# District Summary
# define variables

total_students = len(studentsdataorg_df)

total_budget = schoolsdataorg_df["School Budget"].sum()

mathscore_avg = round(studentsdataorg_df["Math Score"].mean(), 2)
readscore_avg = round(studentsdataorg_df["Reading Score"].mean(), 2)

mathpass = len(studentsdataorg_df.loc[studentsdataorg_df['Math Score'] >= 70])
percent_mathpass = round(mathpass/total_students *100, 2)

readpass = len(studentsdataorg_df.loc[studentsdataorg_df['Reading Score'] >= 70])
percent_readpass = round(readpass/total_students *100, 2)

district_passrate = round((percent_mathpass + percent_readpass)/2, 2)

# %%
# Placed all of the data found into a summary DataFrame for "District Summary"
district_summary_table = ({"Total Students": [total_students],
                              "Total Budget": [total_budget],
                              "Average Math Score": [mathscore_avg],
                              "Average Reading Score": [readscore_avg],
                                "Percent Passing Math": [percent_mathpass],
                                "Percent Passing Reading": [percent_readpass],
                                "Overall Passing Rate": [district_passrate]
                                })
print("District Summary")
district_summary_table
# Out:
# District Summary
# {'Total Students': [39170],
#  'Total Budget': [24649428],
#  'Average Math Score': [78.99],
#  'Average Reading Score': [81.88],
#  'Percent Passing Math': [74.98],
#  'Percent Passing Reading': [85.81],
#  'Overall Passing Rate': [80.4]}

# %%
df_districtsummary = pd.DataFrame([district_summary_table])

df_districtsummary
# Out:
#   Average Math Score Average Reading Score Overall Passing Rate  \
# 0            [78.99]               [81.88]               [80.4]
#
#   Percent Passing Math Percent Passing Reading Total Budget Total Students
# 0              [74.98]                 [85.81]   [24649428]        [39170]

# %%
df_districtsummary.dtypes
# Out:
# Average Math Score         object
# Average Reading Score      object
# Overall Passing Rate       object
# Percent Passing Math       object
# Percent Passing Reading    object
# Total Budget               object
# Total Students             object
# dtype: object

# %%
df_districtsummaryreordered = df_districtsummary[['Total Students', 'Total Budget', 'Average Math Score', 'Average Reading Score',
                                                  'Percent Passing Math', 'Percent Passing Reading','Overall Passing Rate']]

df_districtsummaryreordered
# Out:
#   Total Students Total Budget Average Math Score Average Reading Score  \
# 0        [39170]   [24649428]            [78.99]               [81.88]
#
#   Percent Passing Math Percent Passing Reading Overall Passing Rate
# 0              [74.98]                 [85.81]               [80.4]

# %%
schoolsdataorg_df
# Out:
#     School ID            School Name School Type School Size  School Budget
# 0           0      Huang High School    District       2,917        1910635
# 1           1   Figueroa High School    District       2,949        1884411
# 2           2    Shelton High School     Charter       1,761        1056600
# 3           3  Hernandez High School    District       4,635        3022020
# 4           4    Griffin High School     Charter       1,468         917500
# 5           5     Wilson High School     Charter       2,283        1319574
# 6           6    Cabrera High School     Charter       1,858        1081356
# 7           7     Bailey High School    District       4,976        3124928
# 8           8     Holden High School     Charter         427         248087
# 9           9       Pena High School     Charter         962         585858
# 10         10     Wright High School     Charter       1,800        1049400
# ...

# %%
studentsdata_schoolgroup_df = studentsdataorg_df.groupby(['School Name'])

print(studentsdata_schoolgroup_df)

studentsdata_schoolgroup_df.count()
# Out:
# ...
#                        Student ID  Student Name  Gender  Grade Level  \
# School Name
# Bailey High School           4976          4976    4976         4976
# Cabrera High School          1858          1858    1858         1858
# Figueroa High School         2949          2949    2949         2949
# Ford High School             2739          2739    2739         2739
# Griffin High School          1468          1468    1468         1468
# Hernandez High School        4635          4635    4635         4635
# Holden High School            427           427     427          427
# Huang High School            2917          2917    2917         2917
# Johnson High School          4761          4761    4761         4761
# Pena High School              962           962     962          962
# Rodriguez High School        3999          3999    3999         3999
# Shelton High School          1761          1761    1761         1761
# ...

# %%
student_school_merge_df.head()
# Out:
#    Student ID       Student Name Gender Grade Level        School Name  \
# 0           0       Paul Bradley      M         9th  Huang High School
# 1           1       Victor Smith      M        12th  Huang High School
# 2           2    Kevin Rodriguez      M        12th  Huang High School
# 3           3  Dr. Richard Scott      M        12th  Huang High School
# 4           4         Bonnie Ray      F         9th  Huang High School
#
#    Reading Score  Math Score  School ID School Type School Size  School Budget
# 0             66          79          0    District       2,917        1910635
# 1             94          61          0    District       2,917        1910635
# 2             90          60          0    District       2,917        1910635
# 3             67          58          0    District       2,917        1910635
# 4             97          84          0    District       2,917        1910635

# %%
# Create list of school, type

eachschool_namelisttype = schoolsdataorg_df .set_index(["School Name"])["School Type"]

eachschool_namelisttype
# Out:
# School Name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: School Type, dtype: object

# %%
# total students
eachschool_totalstudents = student_school_merge_df["School Name"].value_counts()
eachschool_totalstudents
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: School Name, dtype: int64

# %%
# total budget
eachschool_namelist_budget = schoolsdataorg_df.groupby(["School Name"]).sum()["School Budget"]

eachschool_namelist_budget
# Out:
# School Name
# Bailey High School       3124928
# Cabrera High School      1081356
# Figueroa High School     1884411
# Ford High School         1763916
# Griffin High School       917500
# Hernandez High School    3022020
# Holden High School        248087
# Huang High School        1910635
# Johnson High School      3094650
# Pena High School          585858
# Rodriguez High School    2547363
# Shelton High School      1056600
# Thomas High School       1043130
# Wilson High School       1319574
# Wright High School       1049400
# Name: School Budget, dtype: int64

# %%
# budget per student

eachschool_budgetperstudent = eachschool_namelist_budget / eachschool_totalstudents

eachschool_budgetperstudent
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# average math scores by school
eachschool_mathaverage = student_school_merge_df.groupby(["School Name"]).mean()["Math Score"]

eachschool_mathaverage
# Out:
# School Name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: Math Score, dtype: float64

# %%
# average reading scores by school

eachschool_readaverage = student_school_merge_df.groupby(["School Name"]).mean()["Reading Score"]

eachschool_readaverage
# Out:
# School Name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: Reading Score, dtype: float64

# %%
# Percent Passing Math by School

school_mathscores_list70 = student_school_merge_df[(student_school_merge_df["Math Score"] >= 70)]
eachschool_percent_mathpass = school_mathscores_list70.groupby(["School Name"]).count()["Student Name"] / eachschool_totalstudents *100

eachschool_percent_mathpass
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
# Percent Passing Reading by School

school_readscores_list70 = student_school_merge_df[(student_school_merge_df["Reading Score"] >= 70)]
eachschool_percent_readpass = school_readscores_list70.groupby(["School Name"]).count()["Student Name"] / eachschool_totalstudents *100

eachschool_percent_readpass
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
# Overall Passing Rate by School

eachschool_passrate = round((eachschool_percent_mathpass+eachschool_percent_readpass)/2, 2)



eachschool_passrate
# Out:
# Bailey High School       74.31
# Cabrera High School      95.59
# Figueroa High School     73.36
# Ford High School         73.80
# Griffin High School      95.27
# Hernandez High School    73.81
# Holden High School       94.38
# Huang High School        73.50
# Johnson High School      73.64
# Pena High School         95.27
# Rodriguez High School    73.29
# Shelton High School      94.86
# Thomas High School       95.29
# Wilson High School       95.20
# Wright High School       94.97
# dtype: float64

# %%
eachschool_summary_table = ({"School Type": eachschool_namelisttype,
                                "School Total Students":eachschool_totalstudents,
                                "School Total Budget": eachschool_namelist_budget,
                                "School Per Student Budget": eachschool_budgetperstudent,
                                "School Average Math Score": eachschool_mathaverage,
                                "School Average Reading Score":eachschool_readaverage,
                                "School Percent Passing Math": eachschool_percent_mathpass,
                                "School Percent Passing Reading": eachschool_percent_readpass,
                                "School Overall Passing Rate": eachschool_passrate})


df_eachschool_summary = pd.DataFrame([eachschool_summary_table])

df_eachschool_summary = df_eachschool_summary[["School Type", "School Total Students","School Total Budget", "School Per Student Budget",
                                               "School Average Math Score", "School Average Reading Score", "School Percent Passing Math",
                                               "School Percent Passing Reading", "School Overall Passing Rate"]]

df_eachschool_summary
# Out:
#                                          School Type  \
# 0  School Name
# Huang High School        District
# ...
#
#                                School Total Students  \
# 0  Bailey High School       4976
# Johnson High Sch...
#
#                                  School Total Budget  \
# 0  School Name
# Bailey High School       3124928
# C...
#
#                            School Per Student Budget  \
# 0  Bailey High School       628.0
# Cabrera High Sc...
#
#                            School Average Math Score  \
# 0  School Name
# Bailey High School       77.048432...
#
#                         School Average Reading Score  \
# 0  School Name
# Bailey High School       81.033963...
#
#                          School Percent Passing Math  \
# 0  Bailey High School       66.680064
# Cabrera Hig...
#
#                       School Percent Passing Reading  \
# 0  Bailey High School       81.933280
# Cabrera Hig...
#
#                          School Overall Passing Rate
# ...
